# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahil7151/my_data_science_project/blob/main/Suicide_Data_Filtration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("master.csv")

# %%
df.head(7)
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
# 5  Albania  1987  female    75+ years            1       35600
# 6  Albania  1987  female  35-54 years            6      278800
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
# ...

# %%
df.tail()
# Out:
#           country  year     sex          age  suicides_no  population  \
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# 27815               2.96  Uzbekistan2014         0.675     63,067,077,179
# 27816               2.58  Uzbekistan2014         0.675     63,067,077,179
# 27817               2.17  Uzbekistan2014         0.675     63,067,077,179
# 27818               1.67  Uzbekistan2014         0.675     63,067,077,179
# 27819               1.46  Uzbekistan2014         0.675     63,067,077,179
#
#        gdp_per_capita ($)    generation
# 27815                2309  Generation X
# ...

# %%
df.size
# Out:
# 333840

# %%
df.shape
# Out:
# (27820, 12)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
df.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# ...

# %%
df["country"].unique()
# Out:
# array(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
#        'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Macau', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
# ...

# %%
df["country"].value_counts()
# Out:
# Mauritius                 382
# Austria                   382
# Netherlands               382
# Iceland                   382
# Brazil                    372
#                          ...
# Bosnia and Herzegovina     24
# Cabo Verde                 12
# Dominica                   12
# Macau                      12
# Mongolia                   10
# Name: country, Length: 101, dtype: int64

# %%
df["country"].value_counts().head(10)
# Out:
# Mauritius      382
# Austria        382
# Netherlands    382
# Iceland        382
# Brazil         372
# Singapore      372
# Ecuador        372
# Spain          372
# Puerto Rico    372
# Mexico         372
# Name: country, dtype: int64

# %%
df["country"].value_counts().tail(10)
# Out:
# Nicaragua                 72
# United Arab Emirates      72
# Oman                      36
# Saint Kitts and Nevis     36
# San Marino                36
# Bosnia and Herzegovina    24
# Cabo Verde                12
# Dominica                  12
# Macau                     12
# Mongolia                  10
# Name: country, dtype: int64

# %%
jap = df[df["country"]=="Japan"]
jap
# Out:
#       country  year     sex          age  suicides_no  population  \
# 13364   Japan  1985    male    75+ years         1340     1791000
# 13365   Japan  1985  female    75+ years         1553     2862400
# 13366   Japan  1985    male  55-74 years         3763     8996900
# 13367   Japan  1985    male  35-54 years         6962    17833300
# 13368   Japan  1985    male  25-34 years         1982     8465800
# ...       ...   ...     ...          ...          ...         ...
# 13731   Japan  2015  female  35-54 years         2024    16991218
# 13732   Japan  2015  female  25-34 years          685     6614211
# 13733   Japan  2015  female  15-24 years          408     5772938
# 13734   Japan  2015    male   5-14 years           62     5553851
# 13735   Japan  2015  female   5-14 years           28     5287719
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 13364              74.82    Japan1985         0.791  1,398,892,744,821
# ...

# %%
jap.count()
# Out:
# country               372
# year                  372
# sex                   372
# age                   372
# suicides_no           372
# population            372
# suicides/100k pop     372
# country-year          372
# HDI for year          120
#  gdp_for_year ($)     372
# gdp_per_capita ($)    372
# generation            372
# dtype: int64

# %%
jap["suicides_no"].describe()
# Out:
# count     372.000000
# mean     2169.091398
# std      2170.876295
# min        12.000000
# 25%       641.500000
# 50%      1641.000000
# 75%      2585.250000
# max      8948.000000
# Name: suicides_no, dtype: float64

# %%
df.country == "Israel"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27815    False
# 27816    False
# 27817    False
# 27818    False
# 27819    False
# Name: country, Length: 27820, dtype: bool

# %%
df[df.country == "Israel"]
# Out:
#       country  year     sex          age  suicides_no  population  \
# 12416  Israel  1985    male    75+ years           24       66600
# 12417  Israel  1985    male  55-74 years           48      249100
# 12418  Israel  1985  female    75+ years           10       75500
# 12419  Israel  1985    male  35-54 years           41      396400
# 12420  Israel  1985  female  55-74 years           28      290900
# ...       ...   ...     ...          ...          ...         ...
# 12783  Israel  2015  female  25-34 years           13      581972
# 12784  Israel  2015  female  35-54 years           20      967412
# 12785  Israel  2015  female  15-24 years            8      617440
# 12786  Israel  2015    male   5-14 years            2      770443
# 12787  Israel  2015  female   5-14 years            1      733603
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 12416              36.04   Israel1985         0.768     27,493,591,484
# ...

# %%
df.loc[(df.country == "Israel") & (df.year == 2015) & (df.age == "25-34 years") & (df.sex == "male"),["country","year","sex","age","suicides_no","population"]]
# Out:
#       country  year   sex          age  suicides_no  population
# 12779  Israel  2015  male  25-34 years           45      586251

# %%
df.loc[(df.country == "Israel") & (df.year == 2015) & (df.sex == "male"),["country","year","sex","age","suicides_no","population"]]
# Out:
#       country  year   sex          age  suicides_no  population
# 12776  Israel  2015  male    75+ years           30      168826
# 12777  Israel  2015  male  55-74 years           65      595247
# 12778  Israel  2015  male  35-54 years           92      944406
# 12779  Israel  2015  male  25-34 years           45      586251
# 12781  Israel  2015  male  15-24 years           35      644674
# 12786  Israel  2015  male   5-14 years            2      770443

# %%
df[(df.year.between(1998,2003)) & (df.country == "Panama")]
# Out:
#       country  year     sex          age  suicides_no  population  \
# 18348  Panama  1998    male  55-74 years           21      124577
# 18349  Panama  1998    male  25-34 years           34      244555
# 18350  Panama  1998    male  15-24 years           36      288189
# 18351  Panama  1998    male    75+ years            3       27984
# 18352  Panama  1998    male  35-54 years           30      298156
# ...       ...   ...     ...          ...          ...         ...
# 18415  Panama  2003  female  55-74 years            2      153054
# 18416  Panama  2003  female  25-34 years            3      264433
# 18417  Panama  2003    male   5-14 years            3      329290
# 18418  Panama  2003  female   5-14 years            0      317030
# 18419  Panama  2003  female    75+ years            0       39497
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 18348              16.86   Panama1998           NaN     11,575,486,400
# ...

# %%
df.loc[(df.year.isin([1998,2003])) & (df.country == "Israel")]
# Out:
#       country  year     sex          age  suicides_no  population  \
# 12572  Israel  1998    male    75+ years           33      103400
# 12573  Israel  1998    male  55-74 years           55      333300
# 12574  Israel  1998  female    75+ years           15      143800
# 12575  Israel  1998    male  25-34 years           42      421100
# 12576  Israel  1998    male  15-24 years           52      534300
# 12577  Israel  1998    male  35-54 years           55      668200
# 12578  Israel  1998  female  55-74 years           21      403400
# 12579  Israel  1998  female  35-54 years           19      705600
# 12580  Israel  1998  female  15-24 years           13      511000
# 12581  Israel  1998  female  25-34 years           10      421100
# 12582  Israel  1998    male   5-14 years            2      571700
# 12583  Israel  1998  female   5-14 years            1      543300
# 12632  Israel  2003    male    75+ years           28      120134
# ...

# %%
df.loc[~(df.year.isin([1998,2003])) & (df.country == "Qatar")]

# ~ tilt indicated excluding this
# Out:
#       country  year     sex          age  suicides_no  population  \
# 20052   Qatar  1995  female  15-24 years            0       24859
# 20053   Qatar  1995  female  25-34 years            0       36029
# 20054   Qatar  1995  female  35-54 years            0       39135
# 20055   Qatar  1995  female   5-14 years            0       43647
# 20056   Qatar  1995  female  55-74 years            0        5879
# ...       ...   ...     ...          ...          ...         ...
# 20225   Qatar  2016  female  25-34 years            2      164901
# 20226   Qatar  2016  female  15-24 years            0       88675
# 20227   Qatar  2016  female  55-74 years            0       26182
# 20228   Qatar  2016  female    75+ years            0        3250
# 20229   Qatar  2016    male    75+ years            0        6093
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 20052               0.00    Qatar1995         0.783      8,137,911,978
# ...

# %%
df.loc[~(df.year.isin([1998,2003])) & (df.country == "Qatar")].year.unique()
# Out:
# array([1995, 2001, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016])
